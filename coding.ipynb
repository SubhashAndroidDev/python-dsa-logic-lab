# %%
s='hello'
start=0
end=s.len-1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 s='hello'
#       2 start=0
# ----> 3 end=s.len-1
#
# AttributeError: 'str' object has no attribute 'len'
